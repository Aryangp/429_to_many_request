# %%
# !pip install "weaviate-client==3.*"
# Out:
# Requirement already satisfied: weaviate-client==3.* in e:\anaconda3\lib\site-packages (3.26.2)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in e:\anaconda3\lib\site-packages (from weaviate-client==3.*) (2.31.0)
# Requirement already satisfied: validators<1.0.0,>=0.21.2 in e:\anaconda3\lib\site-packages (from weaviate-client==3.*) (0.22.0)
# Requirement already satisfied: authlib<2.0.0,>=1.2.1 in e:\anaconda3\lib\site-packages (from weaviate-client==3.*) (1.3.0)
# Requirement already satisfied: cryptography in e:\anaconda3\lib\site-packages (from authlib<2.0.0,>=1.2.1->weaviate-client==3.*) (41.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client==3.*) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client==3.*) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client==3.*) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.30.0->weaviate-client==3.*) (2023.7.22)
# Requirement already satisfied: cffi>=1.12 in e:\anaconda3\lib\site-packages (from cryptography->authlib<2.0.0,>=1.2.1->weaviate-client==3.*) (1.15.1)
# Requirement already satisfied: pycparser in e:\anaconda3\lib\site-packages (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.2.1->weaviate-client==3.*) (2.21)

# %%
import weaviate
import json

# %%
client = weaviate.Client(
    url = "https://new-cluster-testing-ygkcz16f.weaviate.network",  # Replace with your endpoint
    auth_client_secret=weaviate.AuthApiKey(api_key="vHgPx7EyxYacgur3MJxbhBqb8S1i9Cw0C6G8"),  # Replace w/ your Weaviate instance API key
    additional_headers = {
        "X-HuggingFace-Api-Key": "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"  # Replace with your Hugging Face API key
    }
)
# Out:
# e:\Anaconda3\Lib\site-packages\weaviate\warnings.py:121: DeprecationWarning: Dep005: You are using weaviate-client version 3.26.2. The latest version is 4.4.2.
#             Please consider upgrading to the latest version. See https://weaviate.io/developers/weaviate/client-libraries/python for details.
#   warnings.warn(

# %%
import pandas as pd

# %%
df=pd.read_csv("BigBasket Products.csv")
df.head(3)
# Out:
#    index                                 product                category  \
# 0      1  Garlic Oil - Vegetarian Capsule 500 mg        Beauty & Hygiene
# 1      2                   Water Bottle - Orange  Kitchen, Garden & Pets
# 2      3          Brass Angle Deep - Plain, No.2    Cleaning & Household
#
#             sub_category              brand  sale_price  market_price  \
# 0              Hair Care  Sri Sri Ayurveda        220.0         220.0
# 1  Storage & Accessories         Mastercook       180.0         180.0
# 2            Pooja Needs                Trm       119.0         250.0
#
#                      type  rating  \
# 0        Hair Oil & Serum     4.1
# 1  Water & Fridge Bottles     2.3
# 2         Lamp & Lamp Oil     3.4
#
#                                          description
# 0  This Product contains Garlic Oil that is known...
# 1  Each product is microwave safe (without lid), ...
# 2  A perfect gift for all occasions, be it your m...

# %%
def create_schema():
    client.schema.delete_class("CatalogSearchWithDescription")
    class_search_schema={
        "class": "CatalogSearchWithDescription",
        "description": "A class called catalog search with description",
        "vectorizer": "text2vec-huggingface",
        "vectorIndexType": "hnsw",# can be set flat for that refer https://weaviate.io/developers/weaviate/manage-data/collections

        "vectorIndexConfig": {
        "pq": {
        "enabled": True,
        "trainingLimit": 100000,
        "segments": 512 # refer here https://weaviate.io/developers/weaviate/concepts/vector-index#:~:text=HNSW%20is%20an%20algorithm%20that,(adding%20data%20with%20vectors).
        },
        "distance": "cosine",
        },
        "moduleConfig": {
            "text2vec-huggingface": {
            "model": "sentence-transformers/all-MiniLM-L6-v2",
            "options": {
                "waitForModel": True,
                "useGPU": False,
                "useCache": True
            },
            "vectorizeClassName": False
            }
        },
        "properties": [
            {
            "name": "unique_id",
            "dataType": ["int"],
            "description": "user id",
            "moduleConfig": {
                "text2vec-huggingface": {
                "skip": True,
                "vectorizePropertyName": True
                }
            }
            },
            {
            "name": "product_name",
            "dataType": ["text"],
            "description": "product_name",
            "moduleConfig": {
                "text2vec-huggingface": {
                "skip": True,
                "vectorizePropertyName": True
                }
            }
            },

            {
            "name": "product_desc",
            "dataType": ["text"],
            "description": "product description",
            "moduleConfig": {
                "text2vec-huggingface": {
                "skip": True,
                "vectorizePropertyName": True
                }
            }
            },

            {
            "name": "category",
            "dataType": ["text"],
            "description": "category of product",
            "moduleConfig": {
                "text2vec-huggingface": {
                "skip": False,
                "vectorizePropertyName": True
                }
            }
            },
            {
            "name": "sub_category",
            "dataType": ["text"],
            "description": "sub category of product",
            "moduleConfig": {
                "text2vec-huggingface": {
                "skip": False,
                "vectorizePropertyName": True
                }
            }
            },
            {
            "name": "brand",
            "dataType": ["text"],
            "description": "product brand",
            "moduleConfig": {
                "text2vec-huggingface": {
                "skip": False,
                "vectorizePropertyName": True
                }
            }
            },
            {
            "name": "sale_price",
            "dataType": ["number"],
            "description": "color of product",
            "moduleConfig": {
                "text2vec-huggingface": {
                "skip": False,
                "vectorizePropertyName": True
                }
            }
            },
            {
            "name": "product_type",
            "dataType": ["text"],
            "description": "type of product",
            "moduleConfig": {
                "text2vec-huggingface": {
                "skip": False,
                "vectorizePropertyName": True
                }
            }
            },
            {
            "name": "market_price",
            "dataType": ["number"],
            "description": "product title",
            "moduleConfig": {
                "text2vec-huggingface": {
                "skip": False,
                "vectorizePropertyName": True
                }
            }
            },
            {
            "name": "rating",
            "dataType": ["number"],
            "description": "rating",
            "moduleConfig": {
                "text2vec-huggingface": {
                "skip": False,
                "vectorizePropertyName": True
                }
            }
            }
        ]
        }
    client.schema.create_class(class_search_schema)
create_schema()

# %%
schema = client.schema.get()

# Get the schema
try:
    schema = client.schema.get()
    print("Weaviate schema retrieved successfully:")
    print(schema)
except Exception as e:
    print(f"Failed to retrieve Weaviate schema. Error: {e}")
# Out:
# Weaviate schema retrieved successfully:
# {'classes': [{'class': 'CatalogSearchWithDescription', 'description': 'A class called catalog search with description', 'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2}, 'cleanupIntervalSeconds': 60, 'stopwords': {'additions': None, 'preset': 'en', 'removals': None}}, 'moduleConfig': {'text2vec-huggingface': {'model': 'sentence-transformers/all-MiniLM-L6-v2', 'options': {'useCache': True, 'useGPU': False, 'waitForModel': True}, 'vectorizeClassName': False}}, 'multiTenancyConfig': {'enabled': False}, 'properties': [{'dataType': ['int'], 'description': 'user id', 'indexFilterable': True, 'indexSearchable': False, 'moduleConfig': {'text2vec-huggingface': {'skip': True, 'vectorizePropertyName': True}}, 'name': 'unique_id'}, {'dataType': ['text'], 'description': 'product_name', 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-huggingface': {'skip': True, 'vectorizePropertyName': True}}, 'name': 'product_name', 'tokenization': 'word'}, {'dataType': ['text'], 'description': 'product description', 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-huggingface': {'skip': True, 'vectorizePropertyName': True}}, 'name': 'product_desc', 'tokenization': 'word'}, {'dataType': ['text'], 'description': 'category of product', 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-huggingface': {'skip': False, 'vectorizePropertyName': True}}, 'name': 'category', 'tokenization': 'word'}, {'dataType': ['text'], 'description': 'sub category of product', 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-huggingface': {'skip': False, 'vectorizePropertyName': True}}, 'name': 'sub_category', 'tokenization': 'word'}, {'dataType': ['text'], 'description': 'product brand', 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-huggingface': {'skip': False, 'vectorizePropertyName': True}}, 'name': 'brand', 'tokenization': 'word'}, {'dataType': ['number'], 'description': 'color of product', 'indexFilterable': True, 'indexSearchable': False, 'moduleConfig': {'text2vec-huggingface': {'skip': False, 'vectorizePropertyName': True}}, 'name': 'sale_price'}, {'dataType': ['text'], 'description': 'type of product', 'indexFilterable': True, 'indexSearchable': True, 'moduleConfig': {'text2vec-huggingface': {'skip': False, 'vectorizePropertyName': True}}, 'name': 'product_type', 'tokenization': 'word'}, {'dataType': ['number'], 'description': 'product title', 'indexFilterable': True, 'indexSearchable': False, 'moduleConfig': {'text2vec-huggingface': {'skip': False, 'vectorizePropertyName': True}}, 'name': 'market_price'}, {'dataType': ['number'], 'description': 'rating', 'indexFilterable': True, 'indexSearchable': False, 'moduleConfig': {'text2vec-huggingface': {'skip': False, 'vectorizePropertyName': True}}, 'name': 'rating'}], 'replicationConfig': {'factor': 1}, 'shardingConfig': {'virtualPerPhysical': 128, 'desiredCount': 1, 'actualCount': 1, 'desiredVirtualCount': 128, 'actualVirtualCount': 128, 'key': '_id', 'strategy': 'hash', 'function': 'murmur3'}, 'vectorIndexConfig': {'skip': False, 'cleanupIntervalSeconds': 300, 'maxConnections': 64, 'efConstruction': 128, 'ef': -1, 'dynamicEfMin': 100, 'dynamicEfMax': 500, 'dynamicEfFactor': 8, 'vectorCacheMaxObjects': 1000000000000, 'flatSearchCutoff': 40000, 'distance': 'cosine', 'pq': {'enabled': True, 'bitCompression': False, 'segments': 512, 'centroids': 256, 'trainingLimit': 100000, 'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}}}, 'vectorIndexType': 'hnsw', 'vectorizer': 'text2vec-huggingface'}]}

# %%
def add_data(data1):
    uuid = client.data_object.create(
         class_name="CatalogSearchWithDescription",
         data_object=data1
    )
    return uuid
def get_objects(uuid,className):
    data_object = client.data_object.get_by_id(
      uuid,
      class_name=className,
  )
    return json.dumps(data_object,indent=2)

# %%
df.head(3)
# Out:
#    index                                 product                category  \
# 0      1  Garlic Oil - Vegetarian Capsule 500 mg        Beauty & Hygiene
# 1      2                   Water Bottle - Orange  Kitchen, Garden & Pets
# 2      3          Brass Angle Deep - Plain, No.2    Cleaning & Household
#
#             sub_category              brand  sale_price  market_price  \
# 0              Hair Care  Sri Sri Ayurveda        220.0         220.0
# 1  Storage & Accessories         Mastercook       180.0         180.0
# 2            Pooja Needs                Trm       119.0         250.0
#
#                      type  rating  \
# 0        Hair Oil & Serum     4.1
# 1  Water & Fridge Bottles     2.3
# 2         Lamp & Lamp Oil     3.4
#
#                                          description
# 0  This Product contains Garlic Oil that is known...
# 1  Each product is microwave safe (without lid), ...
# 2  A perfect gift for all occasions, be it your m...

# %%
df = df.rename(columns={'product': 'product_name','description':'product_desc','index':'unique_id','type':'product_type'})
df.head(3)
# Out:
#    unique_id                            product_name                category  \
# 0          1  Garlic Oil - Vegetarian Capsule 500 mg        Beauty & Hygiene
# 1          2                   Water Bottle - Orange  Kitchen, Garden & Pets
# 2          3          Brass Angle Deep - Plain, No.2    Cleaning & Household
#
#             sub_category              brand  sale_price  market_price  \
# 0              Hair Care  Sri Sri Ayurveda        220.0         220.0
# 1  Storage & Accessories         Mastercook       180.0         180.0
# 2            Pooja Needs                Trm       119.0         250.0
#
#              product_type  rating  \
# 0        Hair Oil & Serum     4.1
# 1  Water & Fridge Bottles     2.3
# 2         Lamp & Lamp Oil     3.4
#
#                                         product_desc
# 0  This Product contains Garlic Oil that is known...
# 1  Each product is microwave safe (without lid), ...
# 2  A perfect gift for all occasions, be it your m...

# %%
has_null_values = df.isnull().any().any()

# Print the result
if has_null_values:
    print("There are null values in the DataFrame.")
else:
    print("There are no null values in the DataFrame.")
# Out:
# There are null values in the DataFrame.

# %%
def check_null(column):
    null_has=df[column].isnull().any()
    if null_has:
        print(f"{column} has null value")
    else:
        print(f"{column} has no null value")

# %%
mean_value = df['rating'].mean()

# Fill null values in the specified column with the mean value
df['rating'].fillna(mean_value, inplace=True)
check_null("rating")
# Out:
# rating has no null value

# %%
percentage = 20

# Calculate the number of rows to sample based on the percentage
sample_size = int(len(df) * percentage / 100)

# Use the sample method to randomly select the specified percentage of data
test_data = df.sample(n=sample_size)
test_data
test_data = test_data.round(4)  # Adjust the precision as needed
test_data.describe()
# Out:
#           unique_id   sale_price  market_price       rating
# count   5511.000000  5511.000000   5511.000000  5511.000000
# mean   13795.666304   320.645553    380.237392     3.944219
# std     7979.300922   468.584502    572.125276     0.596622
# min        5.000000     5.000000      5.000000     1.000000
# 25%     6906.000000    95.000000    105.000000     3.943400
# 50%    13892.000000   195.000000    225.000000     3.943400
# 75%    20638.500000   355.875000    430.000000     4.200000
# max    27554.000000  6999.000000  10695.000000     5.000000

# %%
def convert_data(df_new):
    rows_as_dicts=[]
    for index, row in df_new.iterrows():
        row_dict = row.to_dict()
        rows_as_dicts.append(row_dict)
    return rows_as_dicts

dict_df=convert_data(test_data)

# %%
dict_df[0].keys()
# Out:
# dict_keys(['unique_id', 'product_name', 'category', 'sub_category', 'brand', 'sale_price', 'market_price', 'product_type', 'rating', 'product_desc'])

# %%
# Settings for displaying the import progress
counter = 0
interval = 20  # print progress every this many records; should be bigger than the batch_size

def add_object(obj) -> None:
    global counter
    properties = {
        "unique_id": obj["unique_id"],
        "product_name": obj["product_name"],
        "category": obj["category"],
        "sub_category": obj["sub_category"],
        "brand": obj["brand"],
        "sale_price": obj["sale_price"],
        "market_price": obj["market_price"],
        "product_type": obj["product_type"],
        "rating": obj["rating"],
        "product_desc": obj["product_desc"],
    }

    client.batch.configure(batch_size=100)  # Configure batch
    with client.batch as batch:
        # Add the object to the batch
        batch.add_data_object(
            data_object=properties,
            class_name="CatalogSearchWithDescription",
            # If you Bring Your Own Vectors, add the `vector` parameter here
            # vector=obj.vector
        )

        # Calculate and display progress
        counter += 1
        if counter % interval == 0:
            print(f"Imported {counter} articles...")

# with pd.read_csv(
#     "jeopardy_1k.csv",
#     usecols=["Question", "Answer", "Category"],
#     chunksize=100,  # number of rows per chunk
# ) as csv_iterator:
#     # Iterate through the dataframe chunks and add each CSV record to the batch
for data_obj in dict_df:
    add_object(data_obj)
    print(f"Finished importing {counter} articles.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File e:\Anaconda3\Lib\site-packages\requests\models.py:511, in PreparedRequest.prepare_body(self, data, files, json)
#     510 try:
# --> 511     body = complexjson.dumps(json, allow_nan=False)
#     512 except ValueError as ve:
#
# File e:\Anaconda3\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File e:\Anaconda3\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#
# File e:\Anaconda3\Lib\json\encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# ValueError: Out of range float values are not JSON compliant
#
# During handling of the above exception, another exception occurred:
#
# InvalidJSONError                          Traceback (most recent call last)
# Cell In[25], line 42
#      35 # with pd.read_csv(
#      36 #     "jeopardy_1k.csv",
#      37 #     usecols=["Question", "Answer", "Category"],
#      38 #     chunksize=100,  # number of rows per chunk
#      39 # ) as csv_iterator:
#      40 #     # Iterate through the dataframe chunks and add each CSV record to the batch
#      41 for data_obj in dict_df:
# ---> 42     add_object(data_obj)
#      43     print(f"Finished importing {counter} articles.")
#
# Cell In[25], line 21, in add_object(obj)
#       7 properties = {
#       8     "unique_id": obj["unique_id"],
#       9     "product_name": obj["product_name"],
#    (...)
#      17     "product_desc": obj["product_desc"],
#      18 }
#      20 client.batch.configure(batch_size=100)  # Configure batch
# ---> 21 with client.batch as batch:
#      22     # Add the object to the batch
#      23     batch.add_data_object(
#      24         data_object=properties,
#      25         class_name="CatalogSearchWithDescription",
#      26         # If you Bring Your Own Vectors, add the `vector` parameter here
#      27         # vector=obj.vector
#      28     )
#      30     # Calculate and display progress
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1646, in Batch.__exit__(self, exc_type, exc_val, exc_tb)
#    1645 def __exit__(self, exc_type: Any, exc_val: Any, exc_tb: Any) -> None:
# -> 1646     self.flush()
#    1647     self.shutdown()
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1252, in Batch.flush(self)
#    1247 def flush(self) -> None:
#    1248     """
#    1249     Flush both objects and references to the Weaviate server and call the callback function
#    1250     if one is provided. (See the docs for `configure` or `__call__` for how to set one.)
#    1251     """
# -> 1252     self._send_batch_requests(force_wait=True)
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1151, in Batch._send_batch_requests(self, force_wait)
#    1149 timeout_occurred = False
#    1150 for done_future in as_completed(self._future_pool):
# -> 1151     response_objects, nr_objects = done_future.result()
#    1153     # handle objects response
#    1154     if response_objects is not None:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
#     [... skipping hidden 1 frame]
#
# Cell In[24], line 42
#      35 # with pd.read_csv(
#      36 #     "jeopardy_1k.csv",
#      37 #     usecols=["Question", "Answer", "Category"],
#      38 #     chunksize=100,  # number of rows per chunk
#      39 # ) as csv_iterator:
#      40 #     # Iterate through the dataframe chunks and add each CSV record to the batch
#      41 for data_obj in dict_df:
# ---> 42     add_object(data_obj)
#      44 print(f"Finished importing {counter} articles.")
#
# Cell In[24], line 21, in add_object(obj)
#       7 properties = {
#       8     "unique_id": obj["unique_id"],
#       9     "product_name": obj["product_name"],
#    (...)
#      17     "product_desc": obj["product_desc"],
#      18 }
#      20 client.batch.configure(batch_size=100)  # Configure batch
# ---> 21 with client.batch as batch:
#      22     # Add the object to the batch
#      23     batch.add_data_object(
#      24         data_object=properties,
#      25         class_name="CatalogSearchWithDescription",
#      26         # If you Bring Your Own Vectors, add the `vector` parameter here
#      27         # vector=obj.vector
#      28     )
#      30     # Calculate and display progress
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1646, in Batch.__exit__(self, exc_type, exc_val, exc_tb)
#    1645 def __exit__(self, exc_type: Any, exc_val: Any, exc_tb: Any) -> None:
# -> 1646     self.flush()
#    1647     self.shutdown()
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1252, in Batch.flush(self)
#    1247 def flush(self) -> None:
#    1248     """
#    1249     Flush both objects and references to the Weaviate server and call the callback function
#    1250     if one is provided. (See the docs for `configure` or `__call__` for how to set one.)
#    1251     """
# -> 1252     self._send_batch_requests(force_wait=True)
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1151, in Batch._send_batch_requests(self, force_wait)
#    1149 timeout_occurred = False
#    1150 for done_future in as_completed(self._future_pool):
# -> 1151     response_objects, nr_objects = done_future.result()
#    1153     # handle objects response
#    1154     if response_objects is not None:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
#     [... skipping hidden 1 frame]
#
# Cell In[20], line 4
#       1 class_name = "CatalogSearchWithDescription"  # Replace with your class name
#       3 client.batch.configure(batch_size=100)  # Configure batch
# ----> 4 with client.batch as batch:
#       5     for data_obj in dict_df:
#       6         batch.add_data_object(
#       7             data_obj,
#       8             class_name,
#       9             # tenant="tenantA"  # If multi-tenancy is enabled, specify the tenant to which the object will be added.
#      10         )
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1646, in Batch.__exit__(self, exc_type, exc_val, exc_tb)
#    1645 def __exit__(self, exc_type: Any, exc_val: Any, exc_tb: Any) -> None:
# -> 1646     self.flush()
#    1647     self.shutdown()
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1252, in Batch.flush(self)
#    1247 def flush(self) -> None:
#    1248     """
#    1249     Flush both objects and references to the Weaviate server and call the callback function
#    1250     if one is provided. (See the docs for `configure` or `__call__` for how to set one.)
#    1251     """
# -> 1252     self._send_batch_requests(force_wait=True)
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1151, in Batch._send_batch_requests(self, force_wait)
#    1149 timeout_occurred = False
#    1150 for done_future in as_completed(self._future_pool):
# -> 1151     response_objects, nr_objects = done_future.result()
#    1153     # handle objects response
#    1154     if response_objects is not None:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# Cell In[20], line 6
#       4 with client.batch as batch:
#       5     for data_obj in dict_df:
# ----> 6         batch.add_data_object(
#       7             data_obj,
#       8             class_name,
#       9             # tenant="tenantA"  # If multi-tenancy is enabled, specify the tenant to which the object will be added.
#      10         )
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:569, in Batch.add_data_object(self, data_object, class_name, uuid, vector, tenant)
#     566 self.__imported_shards.add(Shard(class_name, tenant))
#     568 if self._batching_type:
# --> 569     self._auto_create()
#     571 return uuid
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1242, in Batch._auto_create(self)
#    1239         while self._recommended_num_objects == 0:
#    1240             time.sleep(1)  # block if weaviate is overloaded
# -> 1242         self._send_batch_requests(force_wait=False)
#    1243     return
#    1244 # just in case
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1151, in Batch._send_batch_requests(self, force_wait)
#    1149 timeout_occurred = False
#    1150 for done_future in as_completed(self._future_pool):
# -> 1151     response_objects, nr_objects = done_future.result()
#    1153     # handle objects response
#    1154     if response_objects is not None:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File e:\Anaconda3\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1099, in Batch._flush_in_thread(self, data_type, batch_request)
#    1079 """
#    1080 Flush BatchRequest in current thread/process.
#    1081
#    (...)
#    1095     The request response and number of items sent with the BatchRequest as tuple.
#    1096 """
#    1098 if len(batch_request) != 0:
# -> 1099     response = self._create_data(
#    1100         data_type=data_type,
#    1101         batch_request=batch_request,
#    1102     )
#    1103     return response, len(batch_request)
#    1104 return None, 0
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:693, in Batch._create_data(self, data_type, batch_request)
#     691 while True:
#     692     try:
# --> 693         response = self._connection.post(
#     694             path="/batch/" + data_type,
#     695             weaviate_object=batch_request.get_request_body(),
#     696             params=params,
#     697         )
#     698     except ReadTimeout as error:
#     699         _batch_create_error_handler(
#     700             retry=timeout_count,
#     701             max_retries=self._timeout_retries,
#     702             error=error,
#     703         )
#
# File e:\Anaconda3\Lib\site-packages\weaviate\connect\connection.py:462, in Connection.post(self, path, weaviate_object, params)
#     459     self.embedded_db.ensure_running()
#     460 request_url = self.url + self._api_version_path + path
# --> 462 return self._session.post(
#     463     url=request_url,
#     464     json=weaviate_object,
#     465     headers=self._get_request_header(),
#     466     timeout=self._timeout_config,
#     467     proxies=self._proxies,
#     468     params=params,
#     469 )
#
# File e:\Anaconda3\Lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File e:\Anaconda3\Lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File e:\Anaconda3\Lib\site-packages\requests\sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File e:\Anaconda3\Lib\site-packages\requests\models.py:371, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
# --> 371 self.prepare_body(data, files, json)
#     372 self.prepare_auth(auth, url)
#     374 # Note that prepare_auth must be last to enable authentication schemes
#     375 # such as OAuth to work on a fully prepared request.
#     376
#     377 # This MUST go after prepare_auth. Authenticators could add a hook
#
# File e:\Anaconda3\Lib\site-packages\requests\models.py:513, in PreparedRequest.prepare_body(self, data, files, json)
#     511     body = complexjson.dumps(json, allow_nan=False)
#     512 except ValueError as ve:
# --> 513     raise InvalidJSONError(ve, request=self)
#     515 if not isinstance(body, bytes):
#     516     body = body.encode("utf-8")
#
# InvalidJSONError: Out of range float values are not JSON compliant
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}

# %%
class_name = "CatalogSearchWithDescription"  # Replace with your class name

client.batch.configure(batch_size=100)  # Configure batch
with client.batch as batch:
    for data_obj in dict_df:
        batch.add_data_object(
            data_obj,
            class_name,
            # tenant="tenantA"  # If multi-tenancy is enabled, specify the tenant to which the object will be added.
        )
# Out:
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# ...
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# {'error': [{'message': 'update vector: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}]}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File e:\Anaconda3\Lib\site-packages\requests\models.py:511, in PreparedRequest.prepare_body(self, data, files, json)
#     510 try:
# --> 511     body = complexjson.dumps(json, allow_nan=False)
#     512 except ValueError as ve:
#
# File e:\Anaconda3\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File e:\Anaconda3\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#
# File e:\Anaconda3\Lib\json\encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# ValueError: Out of range float values are not JSON compliant
#
# During handling of the above exception, another exception occurred:
#
# InvalidJSONError                          Traceback (most recent call last)
# Cell In[20], line 4
#       1 class_name = "CatalogSearchWithDescription"  # Replace with your class name
#       3 client.batch.configure(batch_size=100)  # Configure batch
# ----> 4 with client.batch as batch:
#       5     for data_obj in dict_df:
#       6         batch.add_data_object(
#       7             data_obj,
#       8             class_name,
#       9             # tenant="tenantA"  # If multi-tenancy is enabled, specify the tenant to which the object will be added.
#      10         )
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1646, in Batch.__exit__(self, exc_type, exc_val, exc_tb)
#    1645 def __exit__(self, exc_type: Any, exc_val: Any, exc_tb: Any) -> None:
# -> 1646     self.flush()
#    1647     self.shutdown()
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1252, in Batch.flush(self)
#    1247 def flush(self) -> None:
#    1248     """
#    1249     Flush both objects and references to the Weaviate server and call the callback function
#    1250     if one is provided. (See the docs for `configure` or `__call__` for how to set one.)
#    1251     """
# -> 1252     self._send_batch_requests(force_wait=True)
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1151, in Batch._send_batch_requests(self, force_wait)
#    1149 timeout_occurred = False
#    1150 for done_future in as_completed(self._future_pool):
# -> 1151     response_objects, nr_objects = done_future.result()
#    1153     # handle objects response
#    1154     if response_objects is not None:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# Cell In[20], line 6
#       4 with client.batch as batch:
#       5     for data_obj in dict_df:
# ----> 6         batch.add_data_object(
#       7             data_obj,
#       8             class_name,
#       9             # tenant="tenantA"  # If multi-tenancy is enabled, specify the tenant to which the object will be added.
#      10         )
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:569, in Batch.add_data_object(self, data_object, class_name, uuid, vector, tenant)
#     566 self.__imported_shards.add(Shard(class_name, tenant))
#     568 if self._batching_type:
# --> 569     self._auto_create()
#     571 return uuid
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1242, in Batch._auto_create(self)
#    1239         while self._recommended_num_objects == 0:
#    1240             time.sleep(1)  # block if weaviate is overloaded
# -> 1242         self._send_batch_requests(force_wait=False)
#    1243     return
#    1244 # just in case
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1151, in Batch._send_batch_requests(self, force_wait)
#    1149 timeout_occurred = False
#    1150 for done_future in as_completed(self._future_pool):
# -> 1151     response_objects, nr_objects = done_future.result()
#    1153     # handle objects response
#    1154     if response_objects is not None:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File e:\Anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File e:\Anaconda3\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:1099, in Batch._flush_in_thread(self, data_type, batch_request)
#    1079 """
#    1080 Flush BatchRequest in current thread/process.
#    1081
#    (...)
#    1095     The request response and number of items sent with the BatchRequest as tuple.
#    1096 """
#    1098 if len(batch_request) != 0:
# -> 1099     response = self._create_data(
#    1100         data_type=data_type,
#    1101         batch_request=batch_request,
#    1102     )
#    1103     return response, len(batch_request)
#    1104 return None, 0
#
# File e:\Anaconda3\Lib\site-packages\weaviate\batch\crud_batch.py:693, in Batch._create_data(self, data_type, batch_request)
#     691 while True:
#     692     try:
# --> 693         response = self._connection.post(
#     694             path="/batch/" + data_type,
#     695             weaviate_object=batch_request.get_request_body(),
#     696             params=params,
#     697         )
#     698     except ReadTimeout as error:
#     699         _batch_create_error_handler(
#     700             retry=timeout_count,
#     701             max_retries=self._timeout_retries,
#     702             error=error,
#     703         )
#
# File e:\Anaconda3\Lib\site-packages\weaviate\connect\connection.py:462, in Connection.post(self, path, weaviate_object, params)
#     459     self.embedded_db.ensure_running()
#     460 request_url = self.url + self._api_version_path + path
# --> 462 return self._session.post(
#     463     url=request_url,
#     464     json=weaviate_object,
#     465     headers=self._get_request_header(),
#     466     timeout=self._timeout_config,
#     467     proxies=self._proxies,
#     468     params=params,
#     469 )
#
# File e:\Anaconda3\Lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File e:\Anaconda3\Lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File e:\Anaconda3\Lib\site-packages\requests\sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File e:\Anaconda3\Lib\site-packages\requests\models.py:371, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
# --> 371 self.prepare_body(data, files, json)
#     372 self.prepare_auth(auth, url)
#     374 # Note that prepare_auth must be last to enable authentication schemes
#     375 # such as OAuth to work on a fully prepared request.
#     376
#     377 # This MUST go after prepare_auth. Authenticators could add a hook
#
# File e:\Anaconda3\Lib\site-packages\requests\models.py:513, in PreparedRequest.prepare_body(self, data, files, json)
#     511     body = complexjson.dumps(json, allow_nan=False)
#     512 except ValueError as ve:
# --> 513     raise InvalidJSONError(ve, request=self)
#     515 if not isinstance(body, bytes):
#     516     body = body.encode("utf-8")
#
# InvalidJSONError: Out of range float values are not JSON compliant

# %%
import json
for data in dict_df:
#     json_data=json.dumps(data)
    uuid=add_data(data)
    print(uuid)
# uuid=add_data(dict_df[0])
# print(uuid)
# Out:
# 656d15de-5c9d-47cf-8e2e-0942b806e387
# 21ff7d9a-69e1-4f43-afaa-bdc539adf806
# 0d64e825-5080-40f3-8973-895c34601c54
# 04b0a5a9-c86b-40dc-9bfa-2da7b373549d
# 31fa669f-7e7b-4ff9-9149-77a313c00b78
# 2ba52a36-e0d3-4ef3-bee8-ece2417d0de1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 4
#       1 import json
#       2 for data in dict_df:
#       3 #     json_data=json.dumps(data)
# ----> 4     uuid=add_data(data)
#       5     print(uuid)
#       6 # uuid=add_data(dict_df[0])
#       7 # print(uuid)
#
# Cell In[10], line 2, in add_data(data1)
#       1 def add_data(data1):
# ----> 2     uuid = client.data_object.create(
#       3          class_name="CatalogSearchWithDescription",
#       4          data_object=data1
#       5     )
#       6     return uuid
#
# File e:\Anaconda3\Lib\site-packages\weaviate\data\crud_data.py:145, in DataObject.create(self, data_object, class_name, uuid, vector, consistency_level, tenant)
#     143     weaviate_obj["tenant"] = tenant
#     144 try:
# --> 145     response = self._connection.post(path=path, weaviate_object=weaviate_obj, params=params)
#     146 except RequestsConnectionError as conn_err:
#     147     raise RequestsConnectionError("Object was not added to Weaviate.") from conn_err
#
# File e:\Anaconda3\Lib\site-packages\weaviate\connect\connection.py:462, in Connection.post(self, path, weaviate_object, params)
#     459     self.embedded_db.ensure_running()
#     460 request_url = self.url + self._api_version_path + path
# --> 462 return self._session.post(
#     463     url=request_url,
#     464     json=weaviate_object,
#     465     headers=self._get_request_header(),
#     466     timeout=self._timeout_config,
#     467     proxies=self._proxies,
#     468     params=params,
#     469 )
#
# File e:\Anaconda3\Lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File e:\Anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File e:\Anaconda3\Lib\site-packages\requests\sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File e:\Anaconda3\Lib\site-packages\requests\models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File e:\Anaconda3\Lib\site-packages\requests\models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File e:\Anaconda3\Lib\site-packages\urllib3\response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     608 """
#     609 A generator wrapper for the read() method. A call will block until
#     610 ``amt`` bytes have been read from the connection or until the
#    (...)
#     621     'content-encoding' header.
#     622 """
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#     626 else:
#
# File e:\Anaconda3\Lib\site-packages\urllib3\response.py:828, in HTTPResponse.read_chunked(self, amt, decode_content)
#     825     return
#     827 while True:
# --> 828     self._update_chunk_length()
#     829     if self.chunk_left == 0:
#     830         break
#
# File e:\Anaconda3\Lib\site-packages\urllib3\response.py:758, in HTTPResponse._update_chunk_length(self)
#     756 if self.chunk_left is not None:
#     757     return
# --> 758 line = self._fp.fp.readline()
#     759 line = line.split(b";", 1)[0]
#     760 try:
#
# File e:\Anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File e:\Anaconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File e:\Anaconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
response = (
    client.query
    .get("CatalogSearchWithDescription", ["unique_id", "product_name","category","sub_category","brand","sale_price","market_price","product_type","rating","product_desc"])
    .with_near_text({
        "concepts": ["basmati rice which is ready meals"]
    })
    .with_limit(4)
    .with_additional(["distance"])
    .do()
)

print(json.dumps(response, indent=2))
# Out:
# {
#   "data": {
#     "Get": {
#       "CatalogSearchWithDescription": null
#     }
#   },
#   "errors": [
#     {
#       "locations": [
#         {
#           "column": 6,
#           "line": 1
#         }
#       ],
#       "message": "explorer: get class: vectorize params: vectorize params: vectorize params: vectorize keywords: remote client vectorize: failed with status: 429 error: Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate",
#       "path": [
#         "Get",
#         "CatalogSearchWithDescription"
#       ]
#     }
#   ]
# }

# %%
test_data.head(5)
# Out:
#        unique_id                                       product_name  \
# 9822        9823         Instant Pasta Sauce Mix - Tomato Primavera
# 5955        5956                                         Ferra Fish
# 16465      16466           Pants - Extra Absorb Diaper, Medium Size
# 5059        5060                         Tomato Rice - Ready to Eat
# 7823        7824  Magic Seal Oval Storage Plastic Container Tran...
#
#                      category            sub_category             brand  \
# 9822     Gourmet & World Food  Cooking & Baking Needs  Veekes & Company
# 5955        Eggs, Meat & Fish          Fish & Seafood     H.S. Dry Fish
# 16465               Baby Care         Diapers & Wipes          Mamypoko
# 5059   Snacks & Branded Foods     Ready To Cook & Eat     Tasty Nibbles
# 7823   Kitchen, Garden & Pets   Storage & Accessories           Polyset
#
#        sale_price  market_price              product_type  rating  \
# 9822         49.0          49.0  Herbs, Seasonings & Rubs  3.9434
# 5955         59.5          70.0                  Dry Fish  3.9434
# 16465        99.0          99.0                   Diapers  4.2000
# 5059         95.0          95.0    Heat & Eat Ready Meals  3.7000
# 7823        129.0         209.0           Containers Sets  4.2000
#
#                                             product_desc
# 9822   Veekes and company bring to you a creamy tomat...
# 5955   The oldest traditional way of preserving fish ...
# 16465  MamyPoko Pants Extra Absorb Diapers are a pant...
# 5059   This pouch contains cooked basmati rice with t...
# 7823   Polyset Magic Seal is Modular Series is design...

# %%
all_objects = client.data_object.get(class_name="CatalogSearchWithDescription")
print(len(all_objects))
# Out:
# 3
